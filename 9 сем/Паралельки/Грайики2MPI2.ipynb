# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
threads = np.array([1, 4, 9, 16])

# %%
# Время выполнения операций
generation_time = np.array([
    0.0239902,
    0.00605341,
    0.00295075,
    0.00178339
])

fill_time = np.array([
    0.252437,
    0.0634968,
    0.028648,
    0.0163411
])

solve_time = np.array([
    0.179857,
    0.0558435,
    0.0386201,
    0.0343934
])

spmv_time = np.array([
    0.00503372,
    0.00132963,
    0.000595165,
    0.000323385
])

spmv_diag_time = np.array([
    0.00261897,
    0.000720872,
    0.000337024,
    0.000139432
])

dot_time = np.array([
    0.00153399,
    0.000391073,
    0.00019188,
    0.000110961
])

axpy_time = np.array([
    0.00118975,
    0.000261098,
    0.000104778,
    0.0000626
])

# =========================
# Считаем ускорение
# =========================
speedup_generation = generation_time[0] / generation_time
speedup_fill = fill_time[0] / fill_time
speedup_solve = solve_time[0] / solve_time
speedup_spmv  = spmv_time[0] / spmv_time
speedup_spmv_diag = spmv_diag_time[0] / spmv_diag_time
speedup_dot   = dot_time[0]  / dot_time
speedup_axpy  = axpy_time[0] / axpy_time

# =========================
# Строим графики
# =========================
plt.figure(figsize=(36, 6))

# 1️⃣ Время выполнения основных операций
plt.subplot(1, 6, 1)
plt.plot(threads, generation_time, marker='o', linestyle='-', label='Generation')
plt.plot(threads, fill_time, marker='o', linestyle='-', label='Fill')
plt.plot(threads, solve_time, marker='o', linestyle='-', color='red', label='Solve')
plt.title("Время выполнения операций")
plt.xlabel("Потоки")
plt.ylabel("Время(с)")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 2️⃣ Ускорение основных операций
plt.subplot(1, 6, 2)
plt.plot(threads, speedup_generation, marker='o', linestyle='-', label='Generation')
plt.plot(threads, speedup_fill,  marker='o', linestyle='-', label='Fill')
plt.plot(threads, speedup_solve,   marker='o', linestyle='-', color='red', label='Solve')
plt.title("Ускорение")
plt.xlabel("Потоки")
plt.ylabel("Ускорение")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 1️⃣ Время выполнения
plt.subplot(1, 6, 3)
plt.plot(threads, solve_time, marker='o', linestyle='-', color='red', label='Solve')
plt.plot(threads, spmv_time, marker='o', linestyle='-', label='SPMV')
plt.plot(threads, spmv_diag_time, marker='o', linestyle='-', label='SPMVDiag')
plt.plot(threads, dot_time, marker='o', linestyle='-', label='DOT')
plt.plot(threads, axpy_time, marker='o', linestyle='-', label='AXPY')
plt.title("Время выполнения операций")
plt.xlabel("Потоки")
plt.ylabel("Время(с)")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 2️⃣ Ускорение
plt.subplot(1, 6, 4)
plt.plot(threads, speedup_solve, marker='o', linestyle='-', color='red', label='Solve')
plt.plot(threads, speedup_spmv,  marker='o', linestyle='-', label='SPMV')
plt.plot(threads, speedup_spmv_diag, marker='o', linestyle='-', label='SPMVDiag')
plt.plot(threads, speedup_dot,   marker='o', linestyle='-', label='DOT')
plt.plot(threads, speedup_axpy,  marker='o', linestyle='-', label='AXPY')
plt.title("Ускорение")
plt.xlabel("Потоки")
plt.ylabel("Ускорение")
plt.xticks(threads)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Время выполнения операций
generation_time = np.array([
    0.239399,
    0.0610349,
    0.028774,
    0.0179731
])

fill_time = np.array([
    2.53182,
    0.631826,
    0.283456,
    0.16256
])

solve_time = np.array([
    2.00739,
    0.532506,
    0.290454,
    0.240717
])

spmv_time = np.array([
    0.0490284,
    0.0125404,
    0.00607874,
    0.00521719
])

spmv_diag_time = np.array([
    0.0270408,
    0.00692113,
    0.00437714,
    0.00378143
])

dot_time = np.array([
    0.0153396,
    0.00388968,
    0.00178723,
    0.00104941
])

axpy_time = np.array([
    0.0147851,
    0.00438396,
    0.00268924,
    0.00208277
])

# =========================
# Считаем ускорение
# =========================
speedup_generation = generation_time[0] / generation_time
speedup_fill = fill_time[0] / fill_time
speedup_solve = solve_time[0] / solve_time
speedup_spmv  = spmv_time[0] / spmv_time
speedup_spmv_diag = spmv_diag_time[0] / spmv_diag_time
speedup_dot   = dot_time[0]  / dot_time
speedup_axpy  = axpy_time[0] / axpy_time

# =========================
# Строим графики
# =========================
plt.figure(figsize=(36, 6))

# 1️⃣ Время выполнения основных операций
plt.subplot(1, 6, 1)
plt.plot(threads, generation_time, marker='o', linestyle='-', label='Generation')
plt.plot(threads, fill_time, marker='o', linestyle='-', label='Fill')
plt.plot(threads, solve_time, marker='o', linestyle='-', color='red', label='Solve')
plt.title("Время выполнения операций")
plt.xlabel("Потоки")
plt.ylabel("Время(с)")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 2️⃣ Ускорение основных операций
plt.subplot(1, 6, 2)
plt.plot(threads, speedup_generation, marker='o', linestyle='-', label='Generation')
plt.plot(threads, speedup_fill,  marker='o', linestyle='-', label='Fill')
plt.plot(threads, speedup_solve,   marker='o', linestyle='-', color='red', label='Solve')
plt.title("Ускорение")
plt.xlabel("Потоки")
plt.ylabel("Ускорение")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 1️⃣ Время выполнения
plt.subplot(1, 6, 3)
plt.plot(threads, solve_time, marker='o', linestyle='-', color='red', label='Solve')
plt.plot(threads, spmv_time, marker='o', linestyle='-', label='SPMV')
plt.plot(threads, spmv_diag_time, marker='o', linestyle='-', label='SPMVDiag')
plt.plot(threads, dot_time, marker='o', linestyle='-', label='DOT')
plt.plot(threads, axpy_time, marker='o', linestyle='-', label='AXPY')
plt.title("Время выполнения операций")
plt.xlabel("Потоки")
plt.ylabel("Время(с)")
plt.xticks(threads)
plt.legend()
plt.grid(True)

# 2️⃣ Ускорение
plt.subplot(1, 6, 4)
plt.plot(threads, speedup_solve, marker='o', linestyle='-', color='red', label='Solve')
plt.plot(threads, speedup_spmv,  marker='o', linestyle='-', label='SPMV')
plt.plot(threads, speedup_spmv_diag, marker='o', linestyle='-', label='SPMVDiag')
plt.plot(threads, speedup_dot,   marker='o', linestyle='-', label='DOT')
plt.plot(threads, speedup_axpy,  marker='o', linestyle='-', label='AXPY')
plt.title("Ускорение")
plt.xlabel("Потоки")
plt.ylabel("Ускорение")
plt.xticks(threads)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print(speedup_solve)
print(speedup_spmv)
print(speedup_spmv_diag)
print(speedup_dot)
print(speedup_axpy)
# Out:
# [1.         3.769704   6.91121486 8.33921161]
# [1.         3.90963606 8.06555306 9.39747259]
# [1.         3.90699207 6.17773249 7.15094554]
# [ 1.          3.94366632  8.58289084 14.61735642]
# [1.         3.37254446 5.49787301 7.09876751]
